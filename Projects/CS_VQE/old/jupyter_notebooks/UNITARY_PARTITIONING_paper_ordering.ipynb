# %%
import numpy as np
import cs_vqe as c
from copy import deepcopy as copy

import ast
import matplotlib.pyplot as plt
import os

# %%
import tqdm
from tqdm.notebook import tqdm
import Graph as graph

# %%
# working_dir = os.path.dirname(os.path.abspath(__file__)) # gets directory where running python file is!
working_dir = os.getcwd()
data_dir = os.path.join(working_dir, 'data')
data_hamiltonians_file = os.path.join(data_dir, 'hamiltonians.txt')


with open(data_hamiltonians_file, 'r') as input_file:
    hamiltonians = ast.literal_eval(input_file.read())

# %%
for key in hamiltonians.keys():
    print(f"{key: <25}     n_qubits:  {hamiltonians[key][1]:<5.0f}")
# Out:
# H2-S1_STO-3G_singlet          n_qubits:  18
# C1-O1_STO-3G_singlet          n_qubits:  16
# H1-Cl1_STO-3G_singlet         n_qubits:  16
# H1-Na1_STO-3G_singlet         n_qubits:  16
# H2-Mg1_STO-3G_singlet         n_qubits:  17
# H1-F1_3-21G_singlet           n_qubits:  18
# H1-Li1_3-21G_singlet          n_qubits:  18
# Be1_STO-3G_singlet            n_qubits:  5
# H1-F1_STO-3G_singlet          n_qubits:  8
# H1-Li1_STO-3G_singlet         n_qubits:  8
# Ar1_STO-3G_singlet            n_qubits:  13
# F2_STO-3G_singlet             n_qubits:  15
# H1-O1_STO-3G_singlet          n_qubits:  8
# H2-Be1_STO-3G_singlet         n_qubits:  9
# H2-O1_STO-3G_singlet          n_qubits:  10
# H2_3-21G_singlet              n_qubits:  5
# H2_6-31G_singlet              n_qubits:  5
# H3-N1_STO-3G_singlet          n_qubits:  13
# H4-C1_STO-3G_singlet          n_qubits:  14
# Mg1_STO-3G_singlet            n_qubits:  13
# N2_STO-3G_singlet             n_qubits:  15
# Ne1_STO-3G_singlet            n_qubits:  5
# O2_STO-3G_singlet             n_qubits:  15
# H1-Li1-O1_STO-3G_singlet      n_qubits:  18
# H1-He1_STO-3G_singlet         n_qubits:  2
# H3_STO-3G_singlet_1+          n_qubits:  3
# H1-He1_3-21G_singlet_1+       n_qubits:  6
# H3_3-21G_singlet_1+           n_qubits:  9
# H4-N1_STO-3G_singlet_1+       n_qubits:  14

# %%
data_csvqe_results_file = os.path.join(data_dir, 'csvqe_results.txt')
with open(data_csvqe_results_file, 'r') as input_file:
    csvqe_results = ast.literal_eval(input_file.read())

# %%
# # fn_form =hamiltonians['H1-O1_STO-3G_singlet'][5][4]
# # all_mappings = hamiltonians['H1-O1_STO-3G_singlet'][5][3]
# q_vec = hamiltonians['H1-O1_STO-3G_singlet'][5][1]
# r_vec = hamiltonians['H1-O1_STO-3G_singlet'][5][2]
# hamiltonians['H1-O1_STO-3G_singlet'][5][1]

# %% [markdown]
# # Convert into Openfermion format

# %%
import conversion_scripts as conv_scr

# %%
updated_hamiltonians={}
for key in csvqe_results.keys(): # <- note using csvqe_results (has less molecules than hamiltonians.keys())
    

    ham_noncon = hamiltonians[key][3]
    ep_state = [list(hamiltonians[key][5][1]), list(hamiltonians[key][5][2])] # ground state of noncontextual Ham
    ham = hamiltonians[key][2]

    model = c.quasi_model(ham_noncon)
    fn_form = c.energy_function_form(ham_noncon, model)
    
#     _, _, _, ham_out, ham_noncon_out = c.diagonalize_G(model,fn_form,ep_state, ham, ham_noncon)

    N_qubits = hamiltonians[key][1]
    order= csvqe_results[key][-1] # <-- order specified from greedy run by Will
    qubit_removal_order=copy(order)
    
    reduced_Con_hamiltonians = c.get_reduced_hamiltonians(ham ,model, fn_form, ep_state, order)
    
    
    Contextual_Hamiltonian_list=[]
    qNo_list=[]
    for qNo, Ham in enumerate(reduced_Con_hamiltonians):            
#         if c.contextualQ_ham(Ham) is False:
#             raise ValueError('have not found contextual H')
        Ham_Openf = conv_scr.Get_Openfermion_Hamiltonian(Ham)
        Contextual_Hamiltonian_list.append(list(Ham_Openf))
        qNo_list.append(qNo)
    
    updated_hamiltonians[key] = {
                                'encoding':hamiltonians[key][0],
                                'n_qubits': hamiltonians[key][1],
                                'full_H': conv_scr.Get_Openfermion_Hamiltonian(hamiltonians[key][2]),
                                'nonC_H_greedyDFS': conv_scr.Get_Openfermion_Hamiltonian(hamiltonians[key][3]),
                                'FCI':hamiltonians[key][4],                         
                                'gstate_noncon':hamiltonians[key][5], 
                                'Contextual_Hamiltonian_list': Contextual_Hamiltonian_list, #ham_out,   
                                'Contextual_Hamiltonian_qubitNo_list': qNo_list,  
                                'non_Contextual_H': conv_scr.Get_Openfermion_Hamiltonian(ham_noncon),# ham_noncon_out, 
                                'qubit_removal_order':qubit_removal_order
                             }

# %%
print(updated_hamiltonians['Mg1_STO-3G_singlet']['qubit_removal_order'])
# updated_hamiltonians['Mg1_STO-3G_singlet']['Contextual_Hamiltonian_list']
# Out:
# [0, 1, 2, 9, 3, 12, 4, 5, 6, 7, 8, 10, 11]

# %%
# checking keys match!
for key in updated_hamiltonians.keys():
    if key not in csvqe_results.keys():
        raise ValueError(f'{key} not in csvqe_results')

# %%
import tqdm
from tqdm.notebook import tqdm
from quchem.Unitary_Partitioning.Graph import Clique_cover_Hamiltonian

# %%
unitary_paritioning_of_Con_H={}

commutativity_flag = 'AC' ## <- defines relationship between sets!!!
plot_graph = False
Graph_colouring_strategy='largest_first'


for key in tqdm(list(updated_hamiltonians.keys())):
    
    H_con_List = updated_hamiltonians[key]['Contextual_Hamiltonian_list']
    
    
    anti_commuting_different_red_list=[]
    for i, H_con in enumerate(H_con_List):
        n_qubits = updated_hamiltonians[key]['Contextual_Hamiltonian_qubitNo_list'][i]
        anti_commuting_sets = Clique_cover_Hamiltonian(H_con, 
                                                             n_qubits, 
                                                             commutativity_flag, 
                                                             Graph_colouring_strategy)
        
        anti_commuting_different_red_list.append(anti_commuting_sets)
    
    H_con_reduced_and_antiC_set = list(zip(H_con_List, anti_commuting_different_red_list))
    
    unitary_paritioning_of_Con_H[key] = H_con_reduced_and_antiC_set
# Out:
#   0%|          | 0/26 [00:00<?, ?it/s]

# %%
for key in unitary_paritioning_of_Con_H:
    
    H_con_and_antiC_set_list_different_reductions = unitary_paritioning_of_Con_H[key]
    
    for H_con, AC in H_con_and_antiC_set_list_different_reductions:
        AC = len(AC)
        standard=len(list(H_con))
        print(f'AC : {AC: <6} vs standard: {standard: >6}')
    
    print('\n')
# Out:
# AC : 1      vs standard:      1
# AC : 2      vs standard:      3
# AC : 4      vs standard:     10
# AC : 13     vs standard:     35
#
#
# AC : 1      vs standard:      1
# AC : 2      vs standard:      3
# AC : 5      vs standard:     10
# AC : 9      vs standard:     20
# AC : 20     vs standard:     54
# AC : 32     vs standard:    102
#
#
# AC : 1      vs standard:      1
# AC : 2      vs standard:      3
# AC : 4      vs standard:      8
# AC : 13     vs standard:     34
# AC : 19     vs standard:     62
# AC : 26     vs standard:    122
#
#
# AC : 1      vs standard:      1
# AC : 2      vs standard:      3
# AC : 4      vs standard:      8
# AC : 13     vs standard:     34
# AC : 19     vs standard:     62
# AC : 26     vs standard:    122
#
#
# AC : 1      vs standard:      1
# AC : 2      vs standard:      3
# AC : 4      vs standard:     10
# AC : 12     vs standard:     34
# AC : 21     vs standard:     84
# AC : 43     vs standard:    155
# AC : 50     vs standard:    319
#
#
# AC : 1      vs standard:      1
# AC : 2      vs standard:      3
# AC : 5      vs standard:      9
# AC : 14     vs standard:     30
# AC : 34     vs standard:    100
# AC : 44     vs standard:    155
# AC : 61     vs standard:    231
# AC : 84     vs standard:    366
# AC : 113    vs standard:    558
#
#
# AC : 1      vs standard:      1
# AC : 2      vs standard:      2
# AC : 5      vs standard:      9
# AC : 11     vs standard:     30
# AC : 27     vs standard:    100
# AC : 31     vs standard:    157
# AC : 47     vs standard:    237
# AC : 65     vs standard:    372
# AC : 85     vs standard:    564
#
#
# AC : 1      vs standard:      1
# AC : 2      vs standard:      3
# AC : 5      vs standard:      9
# AC : 13     vs standard:     34
# AC : 18     vs standard:     60
# AC : 40     vs standard:    134
# AC : 61     vs standard:    231
# AC : 84     vs standard:    366
# AC : 113    vs standard:    558
#
#
# AC : 1      vs standard:      1
# AC : 2      vs standard:      3
# AC : 4      vs standard:     10
# AC : 11     vs standard:     34
# AC : 19     vs standard:     71
# AC : 30     vs standard:    132
# AC : 51     vs standard:    216
# AC : 61     vs standard:    268
# AC : 84     vs standard:    412
# AC : 107    vs standard:    596
#
#
# AC : 1      vs standard:      1
# AC : 2      vs standard:      3
# AC : 5      vs standard:      8
# AC : 12     vs standard:     34
# AC : 16     vs standard:     66
# AC : 27     vs standard:    138
# AC : 45     vs standard:    238
# AC : 67     vs standard:    378
# AC : 94     vs standard:    574
# AC : 127    vs standard:    786
#
#
# AC : 1      vs standard:      1
# AC : 2      vs standard:      2
# AC : 5      vs standard:      9
# AC : 13     vs standard:     34
# AC : 22     vs standard:     71
# AC : 34     vs standard:    132
# AC : 59     vs standard:    267
# AC : 82     vs standard:    435
# AC : 92     vs standard:    514
# AC : 127    vs standard:    740
# AC : 160    vs standard:   1035
#
#
# AC : 1      vs standard:      1
# AC : 2      vs standard:      3
# AC : 5      vs standard:      9
# AC : 8      vs standard:     20
# AC : 22     vs standard:     71
# AC : 41     vs standard:    153
# AC : 58     vs standard:    273
# AC : 71     vs standard:    428
# AC : 89     vs standard:    652
# AC : 120    vs standard:    894
# AC : 159    vs standard:   1223
# AC : 197    vs standard:   1649
# AC : 242    vs standard:   2130
# AC : 281    vs standard:   2736
#
#
# AC : 1      vs standard:      1
# AC : 2      vs standard:      3
# AC : 5      vs standard:     10
# AC : 9      vs standard:     20
# AC : 18     vs standard:     54
# AC : 32     vs standard:    106
# AC : 45     vs standard:    176
# AC : 64     vs standard:    268
# AC : 74     vs standard:    382
# AC : 104    vs standard:    514
# AC : 117    vs standard:    675
# AC : 130    vs standard:    861
# AC : 173    vs standard:   1131
# AC : 209    vs standard:   1465
#
#
# AC : 1      vs standard:      1
# AC : 2      vs standard:      2
# AC : 4      vs standard:      6
# AC : 8      vs standard:     14
# AC : 16     vs standard:     28
# AC : 27     vs standard:     80
# AC : 40     vs standard:    136
# AC : 63     vs standard:    268
# AC : 88     vs standard:    448
# AC : 104    vs standard:    602
# AC : 140    vs standard:    804
# AC : 166    vs standard:   1049
# AC : 203    vs standard:   1359
# AC : 254    vs standard:   1740
# AC : 286    vs standard:   2194
#
#
# AC : 1      vs standard:      1
# AC : 2      vs standard:      2
# AC : 5      vs standard:      9
# AC : 12     vs standard:     34
# AC : 21     vs standard:     71
# AC : 33     vs standard:    132
# AC : 39     vs standard:    170
# AC : 65     vs standard:    320
# AC : 84     vs standard:    448
# AC : 105    vs standard:    602
# AC : 130    vs standard:    804
# AC : 158    vs standard:   1049
# AC : 190    vs standard:   1359
# AC : 236    vs standard:   1740
# AC : 278    vs standard:   2194
#
#
# AC : 1      vs standard:      1
# AC : 2      vs standard:      3
# AC : 4      vs standard:     10
# AC : 9      vs standard:     26
# AC : 17     vs standard:     52
# AC : 32     vs standard:     95
# AC : 52     vs standard:    170
# AC : 66     vs standard:    257
# AC : 84     vs standard:    378
# AC : 99     vs standard:    527
# AC : 141    vs standard:    721
# AC : 166    vs standard:    883
# AC : 192    vs standard:   1068
# AC : 230    vs standard:   1390
# AC : 272    vs standard:   1765
# AC : 310    vs standard:   2229
#
#
# AC : 1      vs standard:      1
# AC : 2      vs standard:      3
# AC : 4      vs standard:     10
# AC : 9      vs standard:     23
# AC : 17     vs standard:     49
# AC : 32     vs standard:    100
# AC : 58     vs standard:    166
# AC : 70     vs standard:    232
# AC : 86     vs standard:    330
# AC : 108    vs standard:    452
# AC : 126    vs standard:    613
# AC : 153    vs standard:    815
# AC : 193    vs standard:   1068
# AC : 200    vs standard:   1378
# AC : 251    vs standard:   1765
# AC : 290    vs standard:   2229
#
#
# AC : 1      vs standard:      1
# AC : 2      vs standard:      3
# AC : 4      vs standard:     10
# AC : 9      vs standard:     23
# AC : 17     vs standard:     46
# AC : 35     vs standard:    123
# AC : 53     vs standard:    214
# AC : 71     vs standard:    328
# AC : 92     vs standard:    466
# AC : 105    vs standard:    527
# AC : 133    vs standard:    659
# AC : 157    vs standard:    815
# AC : 195    vs standard:   1068
# AC : 205    vs standard:   1154
# AC : 207    vs standard:   1502
# AC : 287    vs standard:   2241
#
#
# AC : 1      vs standard:      1
# AC : 2      vs standard:      3
# AC : 5      vs standard:      9
# AC : 9      vs standard:     22
# AC : 16     vs standard:     56
# AC : 31     vs standard:    126
# AC : 50     vs standard:    216
# AC : 67     vs standard:    320
# AC : 84     vs standard:    448
# AC : 108    vs standard:    642
# AC : 134    vs standard:    884
# AC : 165    vs standard:   1201
# AC : 192    vs standard:   1599
# AC : 230    vs standard:   2104
# AC : 276    vs standard:   2722
# AC : 322    vs standard:   3489
# AC : 387    vs standard:   4409
#
#
# AC : 1      vs standard:      1
# AC : 2      vs standard:      3
# AC : 5      vs standard:      9
# AC : 12     vs standard:     30
# AC : 35     vs standard:    100
# AC : 44     vs standard:    155
# AC : 62     vs standard:    231
# AC : 78     vs standard:    366
# AC : 112    vs standard:    558
# AC : 147    vs standard:    825
# AC : 202    vs standard:   1181
# AC : 235    vs standard:   1515
# AC : 282    vs standard:   1869
# AC : 319    vs standard:   2282
# AC : 395    vs standard:   2976
# AC : 473    vs standard:   3805
# AC : 399    vs standard:   4409
#
#
# AC : 1      vs standard:      1
# AC : 2      vs standard:      3
# AC : 5      vs standard:      9
# AC : 11     vs standard:     30
# AC : 35     vs standard:    100
# AC : 50     vs standard:    188
# AC : 81     vs standard:    325
# AC : 94     vs standard:    403
# AC : 78     vs standard:    486
# AC : 114    vs standard:    756
# AC : 165    vs standard:   1010
# AC : 171    vs standard:   1293
# AC : 193    vs standard:   1599
# AC : 235    vs standard:   2104
# AC : 273    vs standard:   2722
# AC : 332    vs standard:   3489
# AC : 397    vs standard:   4409
#
#
# AC : 1      vs standard:      1
# AC : 2      vs standard:      3
# AC : 5      vs standard:      9
# AC : 8      vs standard:     20
# AC : 22     vs standard:     71
# AC : 31     vs standard:    132
# AC : 51     vs standard:    216
# AC : 65     vs standard:    320
# AC : 80     vs standard:    448
# AC : 91     vs standard:    504
# AC : 112    vs standard:    708
# AC : 138    vs standard:    910
# AC : 161    vs standard:   1131
# AC : 194    vs standard:   1465
# AC : 242    vs standard:   1833
# AC : 274    vs standard:   2285
# AC : 321    vs standard:   2854
# AC : 379    vs standard:   3540
#
#
# AC : 1      vs standard:      1
# AC : 2      vs standard:      3
# AC : 5      vs standard:      9
# AC : 8      vs standard:     20
# AC : 12     vs standard:     35
# AC : 24     vs standard:     89
# AC : 50     vs standard:    192
# AC : 73     vs standard:    327
# AC : 98     vs standard:    497
# AC : 128    vs standard:    718
# AC : 164    vs standard:   1010
# AC : 179    vs standard:   1293
# AC : 194    vs standard:   1599
# AC : 230    vs standard:   2104
# AC : 276    vs standard:   2740
# AC : 338    vs standard:   3489
# AC : 394    vs standard:   4409
# AC : 469    vs standard:   5530
# AC : 551    vs standard:   6852
#
#
# AC : 1      vs standard:      1
# AC : 2      vs standard:      3
# AC : 5      vs standard:     10
# AC : 11     vs standard:     30
# AC : 24     vs standard:     84
# AC : 42     vs standard:    155
# AC : 62     vs standard:    273
# AC : 90     vs standard:    438
# AC : 126    vs standard:    661
# AC : 170    vs standard:    975
# AC : 221    vs standard:   1359
# AC : 245    vs standard:   1521
# AC : 307    vs standard:   2052
# AC : 375    vs standard:   2732
# AC : 433    vs standard:   3289
# AC : 358    vs standard:   3805
# AC : 398    vs standard:   4409
# AC : 466    vs standard:   5530
# AC : 551    vs standard:   6852
#
#
# AC : 1      vs standard:      1
# AC : 2      vs standard:      3
# AC : 4      vs standard:     10
# AC : 9      vs standard:     24
# AC : 17     vs standard:     56
# AC : 33     vs standard:    126
# AC : 50     vs standard:    216
# AC : 76     vs standard:    320
# AC : 97     vs standard:    454
# AC : 118    vs standard:    642
# AC : 153    vs standard:    884
# AC : 191    vs standard:   1201
# AC : 250    vs standard:   1611
# AC : 295    vs standard:   2104
# AC : 370    vs standard:   2722
# AC : 452    vs standard:   3489
# AC : 531    vs standard:   4409
# AC : 640    vs standard:   5530
# AC : 745    vs standard:   6852
#
#
# AC : 1      vs standard:      1
# AC : 2      vs standard:      2
# AC : 4      vs standard:     10
# AC : 13     vs standard:     34
# AC : 20     vs standard:     71
# AC : 32     vs standard:    132
# AC : 54     vs standard:    267
# AC : 92     vs standard:    435
# AC : 102    vs standard:    514
# AC : 134    vs standard:    743
# AC : 168    vs standard:   1028
# AC : 229    vs standard:   1396
# AC : 268    vs standard:   1853
# AC : 341    vs standard:   2425
# AC : 425    vs standard:   3118
# AC : 466    vs standard:   3556
# AC : 555    vs standard:   4480
# AC : 654    vs standard:   5559
# AC : 532    vs standard:   6237

# %%
import pickle
import datetime

# %%
unique_file_id = datetime.datetime.now().strftime('%Y%b%d-%H%M%S%f')

# %%
output_dir = os.path.join(working_dir, 'Pickle_out')

file_name1 = 'EXP_ordering_anticommuting_vs_standard_conH_{}.pickle'.format(unique_file_id)

file_out1=os.path.join(output_dir, file_name1)
with open(file_out1, 'wb') as outfile:
    pickle.dump(unitary_paritioning_of_Con_H, outfile)

file_name2 = 'EXP_ordering_updated_hamiltonians_{}.pickle'.format(unique_file_id)
file_out2=os.path.join(output_dir, file_name2)
with open(file_out2, 'wb') as outfile:
    pickle.dump(updated_hamiltonians, outfile)

# %%
## test if pickle worked
file_name = 'EXP_ordering_anticommuting_vs_standard_conH.pickle'
with open(file_name, 'rb') as infile:
    loaded_dict = pickle.load(infile)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-c1010a91265d> in <module>
#       1 ## test if pickle worked
#       2 file_name = 'EXP_ordering_anticommuting_vs_standard_conH.pickle'
# ----> 3 with open(file_name, 'rb') as infile:
#       4     loaded_dict = pickle.load(infile)
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: 'EXP_ordering_anticommuting_vs_standard_conH.pickle'

# %%
updated_hamiltonians['H3_STO-3G_singlet_1+']

# %% [markdown]
# # Sanity check
# - check the overall energy to see if correct!
